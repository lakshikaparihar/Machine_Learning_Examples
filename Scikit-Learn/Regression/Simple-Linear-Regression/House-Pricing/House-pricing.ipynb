# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("pricing.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
df.columns
# Out:
# Index(['area', 'price'], dtype='object')

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area, df.price, color = "red", marker = "+")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3000]])
# Out:
# array([587979.45205479])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
df['area']=[2000,30000,5000,80000,50000]

# %% [markdown]
# ## How does my linear equation look like?

# %%
# %matplotlib inline
plt.xlabel("area",fontsize="20")
plt.ylabel("price",fontsize="20")
plt.scatter(df.area, df.price, color = "red", marker = "+")
plt.plot(df.area,reg.predict(df[['area']]),color = "blue")

# %%
import pickle
pickle.dump(reg,open("house_prediction_linear_regression.pkl","wb"))
